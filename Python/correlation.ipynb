# %%
! pip install pandas==0.25.
# Out:
# ...
#      ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.6 MB 131.3 kB/s eta 0:01:36
#      --------------------------------------- 0.0/12.6 MB 131.3 kB/s eta 0:01:36
#      --------------------------------------- 0.0/12.6 MB 151.3 kB/s eta 0:01:24
#      --------------------------------------- 0.1/12.6 MB 163.8 kB/s eta 0:01:17
#      --------------------------------------- 0.1/12.6 MB 182.2 kB/s eta 0:01:09
#      --------------------------------------- 0.1/12.6 MB 182.2 kB/s eta 0:01:09
#      --------------------------------------- 0.1/12.6 MB 182.2 kB/s eta 0:01:09
#      --------------------------------------- 0.1/12.6 MB 140.6 kB/s eta 0:01:30
#      --------------------------------------- 0.1/12.6 MB 163.8 kB/s eta 0:01:17
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# import seaborn as sns

# import matplotlib
# import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       2 # import seaborn as sns
#       3
#       4 # import matplotlib
#       5 # import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'
